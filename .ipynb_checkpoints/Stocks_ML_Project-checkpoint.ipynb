# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import sklearn as skl
import tensorflow as tf

# %%
ts = TimeSeries(key='AJH8MF4OQ465LD6H',output_format='pandas')
data, meta_data = ts.get_daily( outputsize='full')
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-f147a797c929> in <module>
#       1 ts = TimeSeries(key='AJH8MF4OQ465LD6H',output_format='pandas')
# ----> 2 data, meta_data = ts.get_daily( outputsize='full')
#       3 data
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     172         def _format_wrapper(self, *args, **kwargs):
#     173             call_response, data_key, meta_data_key = func(
# --> 174                 self, *args, **kwargs)
#     175             if 'json' in self.output_format.lower() or 'pandas' \
#     176                     in self.output_format.lower():
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     120             # key for it and for its meta data.
#     121             function_name, data_key, meta_data_key = func(
# --> 122                 self, *args, **kwargs)
#     123             base_url = AlphaVantage._RAPIDAPI_URL if self.rapidapi else AlphaVantage._ALPHA_VANTAGE_API_URL
#     124             url = "{}function={}".format(base_url, function_name)
#
# TypeError: get_daily() missing 1 required positional argument: 'symbol'

# %%
data['4. close'].plot()
plt.title('Intraday Times Series for the S&P stock')
plt.show()

# %%
X = data

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-ee607e471bc2> in <module>
#       3
#       4 # Fit the scaler
# ----> 5 X_scaler.fit(X_train)
#       6
#       7 # Scale the data
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     698         X = check_array(X, accept_sparse=('csr', 'csc'),
#     699                         estimator=self, dtype=FLOAT_DTYPES,
# --> 700                         force_all_finite='allow-nan')
#     701
#     702         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     554                     "Reshape your data either using array.reshape(-1, 1) if "
#     555                     "your data has a single feature or array.reshape(1, -1) "
# --> 556                     "if it contains a single sample.".format(array))
#     557
#     558         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1.5833160e+18 1.5833196e+18 1.5834933e+18 1.5835014e+18 1.5835005e+18
#  1.5833295e+18 1.5832422e+18 1.5834906e+18 1.5833205e+18 1.5834960e+18
#  1.5833259e+18 1.5833313e+18 1.5832476e+18 1.5834123e+18 1.5833268e+18
#  1.5832413e+18 1.5833349e+18 1.5834879e+18 1.5834069e+18 1.5835104e+18
#  1.5834987e+18 1.5834240e+18 1.5833376e+18 1.5834231e+18 1.5834033e+18
#  1.5832350e+18 1.5834978e+18 1.5833367e+18 1.5833214e+18 1.5832467e+18
#  1.5834051e+18 1.5835050e+18 1.5832323e+18 1.5833241e+18 1.5834078e+18
#  1.5833286e+18 1.5834888e+18 1.5834177e+18 1.5833304e+18 1.5832332e+18
#  1.5835032e+18 1.5832359e+18 1.5832449e+18 1.5834042e+18 1.5834105e+18
#  1.5832503e+18 1.5834951e+18 1.5833322e+18 1.5832395e+18 1.5834159e+18
#  1.5832494e+18 1.5832485e+18 1.5833151e+18 1.5834222e+18 1.5833250e+18
#  1.5834204e+18 1.5832341e+18 1.5832431e+18 1.5834132e+18 1.5832404e+18
#  1.5834186e+18 1.5832386e+18 1.5833232e+18 1.5834087e+18 1.5834996e+18
#  1.5835077e+18 1.5832512e+18 1.5834924e+18 1.5834213e+18 1.5833340e+18
#  1.5833358e+18 1.5834114e+18 1.5834897e+18 1.5832440e+18 1.5833223e+18].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
